# %%
# !pip install tensorflow==2.15.0
# Out:
# Requirement already satisfied: tensorflow==2.15.0 in c:\users\lithesh\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (24.3.7)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.62.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lithesh\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.28.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lithesh\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lithesh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lithesh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lithesh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lithesh\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lithesh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lithesh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lithesh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lithesh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lithesh\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lithesh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lithesh\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.2.2)

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\Users\LITHESH\anaconda3\Lib\site-packages
# Requires: tensorflow-intel
# Required-by:

# %%
import tensorflow as tf
model = tf.keras.models.load_model('toxicity.h5')
# Out:
# WARNING:tensorflow:From c:\Users\LITHESH\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\LITHESH\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# !pip install google-api-python-client
import pandas as pd
import googleapiclient.discovery

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyABP2SteqNGg1ucp3jk5EH9qtE7JqP_MKA"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="-GJgqIJsTME",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="-GJgqIJsTME", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

dfr = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'comments','public'])
dfr.info()
dfr.to_csv("youtube_comments.csv", index=False)
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\lithesh\anaconda3\lib\site-packages (2.122.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in c:\users\lithesh\anaconda3\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in c:\users\lithesh\anaconda3\lib\site-packages (from google-api-python-client) (2.28.2)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\lithesh\anaconda3\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\lithesh\anaconda3\lib\site-packages (from google-api-python-client) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\lithesh\anaconda3\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\lithesh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\lithesh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\lithesh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lithesh\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lithesh\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lithesh\anaconda3\lib\site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\lithesh\anaconda3\lib\site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\lithesh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lithesh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lithesh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lithesh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lithesh\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.2.2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      696 non-null    object
#  1   updated_at  696 non-null    object
#  2   like_count  696 non-null    int64
#  3   comments    696 non-null    object
#  4   public      696 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 22.6+ KB

# %%
dfr.head()
# Out:
#                       author            updated_at  like_count  \
# 0        @ActionBronsonMusic  2023-10-23T17:53:02Z         592
# 1        @charlesruffing5606  2024-02-13T04:29:12Z           0
# 2  @tannerdempster-walsh4962  2024-02-06T20:30:55Z           1
# 3                @donlee1308  2024-02-01T23:40:27Z           0
# 4                @mehdiflood  2024-02-01T00:47:00Z           0
#
#                                             comments  public
# 0                                  PARIS. WITH LOVE.    True
# 1  My Cats are junkies for this video...They try ...    True
# 2  Bro getting drunk all day and eating magical f...    True
# 3  hands down, the fuckin best food and wine seri...    True
# 4                                            Clovis!    True

# %%
from tensorflow.keras.layers import TextVectorization
MAX_FEATURES = 200000
vectorizer = TextVectorization(max_tokens=MAX_FEATURES,
                               output_sequence_length=1800,
                               output_mode='int')

# %%
import numpy as np
from tensorflow.keras.layers import TextVectorization

MAX_FEATURES = 200000
vectorizer = TextVectorization(max_tokens=MAX_FEATURES,
                               output_sequence_length=1800,
                               output_mode='int')
vectorizer.adapt(dfr['comments']) 
input_text = vectorizer(np.array(dfr['comments']))  
res = model.predict(input_text)
binary_predictions = (res > 0.5).astype(int)
toxic_comments_list = []
for i, prediction in enumerate(binary_predictions):
    if 1 in prediction:
        toxic_comments_list.append({
            'author': dfr['author'][i],
            'updated_at': dfr['updated_at'][i],
            'comments': dfr['comments'][i],
            'prediction[toxic,severe_toxic,obscene,threat,insult,identity_hate]': prediction.tolist()
        })

toxic_comments_df = pd.DataFrame(toxic_comments_list)
print(toxic_comments_df)
# Out:
# WARNING:tensorflow:From c:\Users\LITHESH\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 22/22 [==============================] - 6s 188ms/step
# Toxic Comments DataFrame:
#                    author            updated_at  \
# 0        @jenkornblum3795  2024-01-17T12:02:18Z
# 1           @lepraise1695  2023-11-16T21:21:28Z
# 2           @masutakh2917  2023-11-03T13:28:37Z
# 3            @HandyDandy6  2023-10-31T05:23:02Z
# 4                @boi4354  2023-10-31T00:23:10Z
# 5      @tyronebennett5223  2023-10-28T15:00:06Z
# 6              @pilouraph  2023-10-28T03:40:46Z
# 7              @lexarus79  2023-10-26T07:54:55Z
# 8            @dharker7595  2023-10-25T23:55:35Z
# 9              @smarc1325  2023-10-25T18:48:32Z
# 10         @renosance8941  2023-10-25T18:46:43Z
# 11       @Digitalgirl.mp3  2023-10-25T15:59:08Z
# 12             @jaredm730  2023-10-25T15:26:29Z
# 13         @simonlkdr8618  2023-10-25T14:52:40Z
# 14                @srik88  2023-10-24T23:23:33Z
# 15      @juliuspietsch809  2023-10-24T22:36:05Z
# 16            @sessions22  2023-10-24T18:28:48Z
# 17                @emi786  2023-10-24T13:26:12Z
# 18              @JordanLR  2023-10-24T13:02:46Z
# 19             @EliaMedri  2023-10-24T09:04:50Z
# 20               @esa1002  2023-10-24T06:35:17Z
# 21      @johnmcauslan4620  2023-10-24T06:00:12Z
# 22       @Scuuuuuubbaaaaa  2023-10-24T04:43:00Z
# 23     @RealNyGiantsMafia  2023-10-24T02:37:19Z
# 24      @isaiahrivera1720  2023-10-24T01:55:09Z
# 25          @alexbaek4744  2023-10-24T00:18:31Z
# 26              @jonderic  2023-10-23T23:58:25Z
# 27               @sylarfx  2023-10-23T22:56:26Z
# 28         @russasher6962  2023-10-23T22:39:42Z
# 29               @mjdf122  2023-10-23T22:28:12Z
# 30              @JBones07  2023-10-23T21:57:20Z
# 31  @sebastianlohmann7544  2023-10-23T21:42:37Z
# 32                @TLVRBL  2023-10-23T19:48:00Z
# 33            @Luka-hc5vx  2023-10-23T19:43:29Z
# 34     @miguelramirez7175  2023-10-23T18:52:04Z
# 35     @matanmorovitz8045  2023-10-23T17:44:05Z
# 36         @adriankox8010  2023-10-23T17:40:00Z
# 37            @redrde7066  2023-10-23T17:09:02Z
# 38         @djphantom1823  2023-10-23T16:52:36Z
# 39          @gusblack3699  2023-10-23T16:45:13Z
# 40         @sunilpatel217  2023-10-23T16:20:55Z
# 41           @richardcore  2023-10-23T16:09:59Z
# 42        @mattnorman4007  2023-10-23T16:08:42Z
# 43       @peytonbowen2364  2023-10-23T15:47:56Z
# 44       @cecilharris1196  2023-10-23T15:06:18Z
#
#                                              comments  \
# 0   so this is great! one thing I am missing is wh...
# 1   Thank you for bringing out another season. I'v...
# 2   1:35 always doubt and find out about what you ...
# 3   Action talks like trump if he was smoking on t...
# 4   NO FUCKING WAY IVE BEEN WAITING FOR ANOTHER PA...
# 5   The pause that Action took when he heard the s...
# 6   Oh boy I missed you guys. Aged liked fine wine...
# 7   I swear I’m eating and tasting wine with these...
# 8   Clovis and your fine self need to do your take...
# 9   LOL Feeding those BedBugs Action...   Wonderfu...
# 10  This makes me happy in my soul. 🎉\nEdit: Clovi...
# 11                                            Yay!!!!
# 12  Clovis. Fukng Clovis.\nSo many questions...\nW...
# 13             Bruh what kind of dentition dudes have
# 14  Awesome 🎉 let's get it, a series in any city h...
# 15                  this duo is is fucking incredible
# 16  Some tell me natural wines i can go buy right ...
# 17  I always watch your show when I'm eating, othe...
# 18  Disclaimer guys drinking your own piss isn’t g...
# 19  Action and Clovis one of the best couple ever,...
# 20         i love this kind of duo... Action x Clovis
# 21  Bro no way we got another FTD in Paris with Cl...
# 22                                   Incredible watch
# 23  That Bosquet natural wine looked & poured out ...
# 24       Every single thing on this episode looked 🔥🔥
# 25  Idk why but I get Bourdain vibes from Bronson,...
# 26  Action blessing us with another Paris trip. Go...
# 27                        C'est la vie. Savoir vivre.
# 28  The Passion Shines Through\nThanks for Sharing...
# 29                       Ochin Clovis 🍇 the good days
# 30                          Peace from California! ✌🏽
# 31  Imagine hanging out with these guys. Couldn’t ...
# 32                                  Another classic 🍷
# 33                                 Clovis the mad man
# 34                                               🐐🐐’s
# 35  Yo that  Szechuan eggplant with the cream look...
# 36  Another From Paris with Love Series ?????? FCK...
# 37  We need another larger run of Bronson shoes th...
# 38  Don’t blow up drinking and eating to much acti...
# 39                Clovis’ teeth have seen better days
# 40  Awesome FCUK,  stay in France 🇫🇷 and show one ...
# 41                   Ah, another journey of pleasure!
# 42  Any winos know what some of those raspberry pi...
# 43  Blurring out a French man smoking a cigarette ...
# 44  Action and Clovis needs their own show just ab...
#
#    prediction[toxic,severe_toxic,obscene,threat,insult,identity_hate]
# 0                                  [1, 0, 0, 0, 0, 0]
# 1                                  [1, 0, 1, 0, 0, 0]
# 2                                  [1, 0, 1, 0, 1, 0]
# 3                                  [1, 0, 0, 0, 0, 0]
# 4                                  [1, 0, 1, 0, 0, 0]
# 5                                  [1, 0, 1, 0, 0, 0]
# 6                                  [1, 0, 0, 0, 0, 0]
# 7                                  [1, 0, 0, 0, 1, 0]
# 8                                  [1, 0, 1, 0, 0, 0]
# 9                                  [1, 0, 1, 0, 0, 0]
# 10                                 [1, 0, 1, 0, 0, 0]
# 11                                 [1, 0, 0, 0, 0, 0]
# 12                                 [1, 0, 0, 0, 0, 0]
# 13                                 [1, 0, 1, 0, 0, 0]
# 14                                 [1, 0, 1, 0, 0, 0]
# 15                                 [1, 0, 1, 0, 1, 0]
# 16                                 [1, 0, 0, 0, 0, 0]
# 17                                 [1, 0, 0, 0, 0, 0]
# 18                                 [1, 0, 1, 0, 0, 0]
# 19                                 [1, 0, 1, 0, 0, 0]
# 20                                 [1, 0, 1, 0, 1, 0]
# 21                                 [1, 0, 1, 0, 0, 0]
# 22                                 [1, 0, 1, 0, 1, 0]
# 23                                 [1, 0, 0, 0, 0, 0]
# 24                                 [1, 0, 0, 0, 1, 0]
# 25                                 [1, 0, 0, 0, 0, 0]
# 26                                 [1, 0, 1, 0, 0, 0]
# 27                                 [1, 0, 1, 0, 0, 0]
# 28                                 [1, 0, 0, 0, 0, 0]
# 29                                 [1, 0, 1, 0, 0, 0]
# 30                                 [1, 0, 1, 0, 1, 0]
# 31                                 [1, 0, 1, 0, 1, 0]
# 32                                 [1, 0, 1, 0, 0, 0]
# 33                                 [1, 0, 1, 0, 1, 0]
# 34                                 [1, 0, 0, 0, 0, 0]
# 35                                 [1, 0, 0, 0, 0, 0]
# 36                                 [1, 0, 1, 0, 1, 0]
# 37                                 [1, 0, 1, 0, 0, 0]
# 38                                 [1, 0, 1, 0, 0, 0]
# 39                                 [1, 0, 1, 0, 0, 0]
# 40                                 [1, 0, 1, 0, 0, 0]
# 41                                 [1, 0, 1, 0, 0, 0]
# 42                                 [1, 0, 0, 0, 0, 0]
# 43                                 [1, 0, 0, 0, 0, 0]
# 44                                 [1, 0, 0, 0, 0, 0]

# %%
toxic_comments_df.head(5)
# Out:
#              author            updated_at  \
# 0  @jenkornblum3795  2024-01-17T12:02:18Z
# 1     @lepraise1695  2023-11-16T21:21:28Z
# 2     @masutakh2917  2023-11-03T13:28:37Z
# 3      @HandyDandy6  2023-10-31T05:23:02Z
# 4          @boi4354  2023-10-31T00:23:10Z
#
#                                             comments  \
# 0  so this is great! one thing I am missing is wh...
# 1  Thank you for bringing out another season. I'v...
# 2  1:35 always doubt and find out about what you ...
# 3  Action talks like trump if he was smoking on t...
# 4  NO FUCKING WAY IVE BEEN WAITING FOR ANOTHER PA...
#
#   prediction[toxic,severe_toxic,obscene,threat,insult,identity_hate]
# 0                                 [1, 0, 0, 0, 0, 0]
# 1                                 [1, 0, 1, 0, 0, 0]
# 2                                 [1, 0, 1, 0, 1, 0]
# 3                                 [1, 0, 0, 0, 0, 0]
# 4                                 [1, 0, 1, 0, 0, 0]

# %%
import pandas as pd

entered_text = input("Enter the comment to check: ")

# Vectorize the entered comment
entered_text_vectorized = vectorizer([entered_text])

# Make predictions using the model
entered_res = model.predict(entered_text_vectorized)

# Convert predictions to binary (0 or 1) based on a threshold (0.5 in this case)
binary_prediction = (entered_res > 0.5).astype(int)[0]

# Create a list to store toxic comments
entered_toxic_comments_list = []

# Display the entered comment and prediction
entered_toxic_comments_list.append({
    'comment': entered_text,
    'prediction[toxic,severe_toxic,obscene,threat,insult,identity_hate]': binary_prediction.tolist()
})

# Create a DataFrame from the list
entered_toxic_comments_df = pd.DataFrame(entered_toxic_comments_list)

# Print the DataFrame
print("\nEntered Comment Prediction:")
print(entered_toxic_comments_df)
# Out:
# 1/1 [==============================] - 0s 121ms/step
#
# Entered Comment Prediction:
#                    comment  \
# 0  i feel like killing you
#
#   prediction[toxic,severe_toxic,obscene,threat,insult,identity_hate]
# 0                                 [0, 0, 0, 0, 0, 0]
